# %% [markdown]
# # Yami Test

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
t = np.arange(0,3.6,0.2)
plt.plot(t,t,"b--")
plt.show()
plt.plot(t,t,"b--",t,t**2,"ys")
plt.show()
plt.plot(t,t,"b--",t,t**2,"ys",t,t**3,'g^')
plt.show()
